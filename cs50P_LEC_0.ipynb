# %% [markdown]
# ##### Problem: Indoor voice

# %%
text = input("Write some text: ").lower().split()
clean_text = " ".join(text)
print(clean_text)
# Out:
# my name is musa kaleem

# %% [markdown]
# ##### problem: playback speed

# %%
text = input("Write some text: ").replace(" ", "...")
print(text)
# Out:
# my...name...sis

# %% [markdown]
# ##### Einstein Energy Calculator

# %%
c = 300000000
mass = int(input("Enter mass(kg): "))
e = mass * (c**2)
print(f"{e}")
# Out:
# 90000000000000000

# %% [markdown]
# ##### Making Faces

# %%
def convert(text):
    text = text.replace(":(", " 😀 ")
    text = text.replace(":)", " 😀 ")
    return text


def main():
    print(convert("hello :( good bye :)"))


if __name__ == "__main__":
    main()
# Out:
# hello  😀  good bye  😀
